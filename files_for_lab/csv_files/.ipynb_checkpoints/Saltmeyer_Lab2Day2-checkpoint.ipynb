# %%
# Lab2 Day 2
import pandas as pd
customers = pd.read_csv('marketing_customer_analysis.csv')

# %%
display(customers)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
customers.shape
# Out:
# (10910, 26)

# %%
# Standardize Header Names. What? 
# cols = []
cols = []
for i in range(len(customers.columns)):
    cols.append(customers.columns[i].lower())
customers.columns=cols

# %%
customers.columns = customers.columns.str.replace(' ', '_')
# Replacing spaces with underscores

# %%
# Removing column 'unnamed:_0'   data = data.drop(['tcode','percent_income_donated','very_generous'], axis=1)
customers = customers.drop(('unnamed:_0'), axis=1)

# %%
customers.dtypes
# Total Claim Amount  , Number of Open Complaints, Months Since Last Claim , Customer Lifetime Value   are numerical
# The rest ist categorical
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# vehicle_size                      object
# vehicle_type                      object
# dtype: object

# %%
# NaN Values donors.isna().sum()
customers.isna().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# dtype: int64

# %%
# Percentages of NaN
# nulls_df = pd.DataFrame(round(donors.isna().sum()/len(donors),4)*100)
#nulls_df
#nulls_df = nulls_df.reset_index()
#nulls_df
#nulls_df.columns = ['header_name', 'percent_nulls']
#nulls_df
round(customers.isna().sum()/len(customers),4)*100

nulls_customers = pd.DataFrame(round(customers.isna().sum()/len(customers),4)*100)
nulls_customers
nulls_customers = nulls_customers.reset_index()
nulls_customers
nulls_customers.columns = ['header_name', 'percent_nulls']
nulls_customers
# Out:
#                       header_name  percent_nulls
# 0                        customer           0.00
# 1                           state           5.78
# 2         customer_lifetime_value           0.00
# 3                        response           5.78
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective_to_date           0.00
# 7                employmentstatus           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location_code           0.00
# 11                 marital_status           0.00
# 12           monthly_premium_auto           0.00
# 13        months_since_last_claim           5.80
# 14  months_since_policy_inception           0.00
# 15      number_of_open_complaints           5.80
# 16             number_of_policies           0.00
# 17                    policy_type           0.00
# 18                         policy           0.00
# 19               renew_offer_type           0.00
# 20                  sales_channel           0.00
# 21             total_claim_amount           0.00
# 22                  vehicle_class           5.70
# 23                   vehicle_size           5.70
# 24                   vehicle_type          50.25

# %%
#Replacing Nan's for months since last claim: Use the most frequent number
import numpy as np
months_since_last_claim = customers['months_since_last_claim'].mean()
months_since_last_claim
customers['months_since_last_claim'] = customers['months_since_last_claim'].fillna(months_since_last_claim)

# %%
# Use most common value to fill NaN's for categorial columns: vehicle_class , vehicle_size , respone and state
customers['state'].value_counts()
#donors['gender'].value_counts()
#customers['state'] = customers['state'].fillna
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64

# %%
customers['state'] = customers['state'].fillna('California')

# %%
customers['vehicle_class'].value_counts()
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle_class, dtype: int64

# %%
customers['vehicle_class'] = customers['vehicle_class'].fillna('Four-Door Car')

# %%
customers['vehicle_size'].value_counts()
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# Name: vehicle_size, dtype: int64

# %%
customers['vehicle_size'] = customers['vehicle_size'].fillna('Medsize')

# %%
customers['response'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: response, dtype: int64

# %%
customers['respone'] = customers['response'].fillna('No')

# %%
# Column vehicle_type has 50.25% of NaN's or more specifically misssing values which makes it not fit for use.
# It cannot produce reliable data or conclusion. In a real world case I would suggest to drop the column. 
# I will not do this here though, just to keep the data just in case for the future.

# %%
display(customers)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# 0       College           2/18/11         Employed      M   48029  ...
# 1       College           1/18/11       Unemployed      F       0  ...
# 2      Bachelor           2/10/11         Employed      M   22139  ...
# 3       College           1/11/11         Employed      M   49078  ...
# 4      Bachelor           1/17/11    Medical Leave      F   23675  ...
# ...         ...               ...              ...    ...     ...  ...
# 10905  Bachelor           1/19/11       Unemployed      F       0  ...
# 10906   College            1/6/11         Employed      F   61146  ...
# 10907  Bachelor            2/6/11         Employed      F   39837  ...
# 10908   College           2/13/11         Employed      F   64195  ...
# 10909  Bachelor            1/8/11       Unemployed      M       0  ...
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 0      Corporate Auto  Corporate L3            Offer3          Agent
# 1       Personal Auto   Personal L3            Offer4    Call Center
# 2       Personal Auto   Personal L3            Offer3    Call Center
# 3      Corporate Auto  Corporate L3            Offer2         Branch
# 4       Personal Auto   Personal L2            Offer1         Branch
# ...               ...           ...               ...            ...
# 10905   Personal Auto   Personal L1            Offer3            Web
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10907  Corporate Auto  Corporate L3            Offer1            Web
# 10908   Personal Auto   Personal L1            Offer1         Branch
# 10909   Personal Auto   Personal L1            Offer4            Web
#
#        total_claim_amount  vehicle_class  vehicle_size vehicle_type respone  \
# 0              292.800000  Four-Door Car       Medsize          NaN      No
# 1              744.924331  Four-Door Car       Medsize          NaN      No
# 2              480.000000            SUV       Medsize            A      No
# 3              484.013411  Four-Door Car       Medsize            A     Yes
# 4              707.925645  Four-Door Car       Medsize          NaN      No
# ...                   ...            ...           ...          ...     ...
# 10905         1214.400000     Luxury Car       Medsize            A      No
# 10906          273.018929  Four-Door Car       Medsize            A      No
# 10907          381.306996     Luxury SUV       Medsize          NaN      No
# 10908          618.288849            SUV       Medsize            A      No
# 10909         1021.719397            SUV       Medsize          NaN      No
#
#       month
# 0         2
# 1         1
# 2         2
# 3         1
# 4         1
# ...     ...
# 10905     1
# 10906     1
# 10907     2
# 10908     2
# 10909     1
#
# [10910 rows x 27 columns]

# %%
customers['month'] = pd.DatetimeIndex(customers['effective_to_date']).month
# Source: https://www.codegrepper.com/code-examples/python/extract+month+from+datetime+pandas

# %%
customers.head(60)
# Out:
#    customer       state  customer_lifetime_value response  coverage  \
# 0   DK49336     Arizona              4809.216960       No     Basic
# 1   KX64629  California              2228.525238       No     Basic
# 2   LZ68649  Washington             14947.917300       No     Basic
# 3   XL78013      Oregon             22332.439460      Yes  Extended
# 4   QA50777      Oregon              9025.067525       No   Premium
# 5   HO81102  California              4745.181764      NaN     Basic
# 6   IW72280  California              5035.035257       No     Basic
# 7   IH64929  California              4956.247235       No     Basic
# 8   FM55990  California              5989.773931      Yes   Premium
# 9   QX31376      Oregon             17114.328150       No  Extended
# 10  HG93801     Arizona              5154.764074       No  Extended
# 11  GE63585  California              2420.711888      NaN     Basic
# 12  EO51920      Oregon             19955.257130       No  Extended
# 18  ...   Personal Auto   Personal L3            Offer1          Agent
# 19  ...   Personal Auto   Personal L2            Offer2    Call Center
# 20  ...   Personal Auto   Personal L3            Offer1    Call Center
# 21  ...   Personal Auto   Personal L1            Offer1          Agent
# 22  ...   Personal Auto   Personal L3            Offer2    Call Center
# 23  ...   Personal Auto   Personal L2            Offer1          Agent
# 24  ...  Corporate Auto  Corporate L1            Offer1          Agent
# 25  ...    Special Auto    Special L3            Offer4          Agent
# 26  ...   Personal Auto   Personal L3            Offer3         Branch
# 27  ...   Personal Auto   Personal L3            Offer2          Agent
# 28  ...    Special Auto    Special L2            Offer2    Call Center
# 29  ...   Personal Auto   Personal L2            Offer4    Call Center
# 30  ...   Personal Auto   Personal L3            Offer1         Branch
# 31  ...  Corporate Auto  Corporate L2            Offer2         Branch
# 32  ...  Corporate Auto  Corporate L3            Offer1    Call Center
# 33  ...   Personal Auto   Personal L1            Offer1         Branch
# 34  ...   Personal Auto   Personal L3            Offer2    Call Center
# 35  ...    Special Auto    Special L3            Offer1         Branch
# 36  ...   Personal Auto   Personal L2            Offer3    Call Center
# 37  ...  Corporate Auto  Corporate L2            Offer3          Agent
# 38  ...   Personal Auto   Personal L1            Offer2            Web
# 39  ...   Personal Auto   Personal L2            Offer2            Web
# 40  ...   Personal Auto   Personal L2            Offer2         Branch
# 41  ...  Corporate Auto  Corporate L3            Offer1          Agent
# 42  ...   Personal Auto   Personal L3            Offer1            Web
# 43  ...   Personal Auto   Personal L3            Offer2          Agent
# 44  ...   Personal Auto   Personal L1            Offer4    Call Center
# 45  ...   Personal Auto   Personal L1            Offer3            Web
# 46  ...   Personal Auto   Personal L3            Offer1         Branch
# 47  ...   Personal Auto   Personal L3            Offer2            Web
# 48  ...  Corporate Auto  Corporate L2            Offer1         Branch
# 49  ...   Personal Auto   Personal L3            Offer3    Call Center
# 50  ...   Personal Auto   Personal L3            Offer3            Web
# 51  ...   Personal Auto   Personal L1            Offer1          Agent
# 52  ...   Personal Auto   Personal L3            Offer3    Call Center
# 53  ...   Personal Auto   Personal L3            Offer4    Call Center
# 54  ...   Personal Auto   Personal L1            Offer1         Branch
# 55  ...    Special Auto    Special L3            Offer1          Agent
# 56  ...   Personal Auto   Personal L3            Offer1    Call Center
# 57  ...   Personal Auto   Personal L3            Offer1         Branch
# 58  ...   Personal Auto   Personal L3            Offer4    Call Center
# 59  ...   Personal Auto   Personal L3            Offer2    Call Center
#
#     total_claim_amount  vehicle_class  vehicle_size vehicle_type respone month
# 0           292.800000  Four-Door Car       Medsize          NaN      No     2
# 1           744.924331  Four-Door Car       Medsize          NaN      No     1
# 2           480.000000            SUV       Medsize            A      No     2
# 3           484.013411  Four-Door Car       Medsize            A     Yes     1
# 4           707.925645  Four-Door Car       Medsize          NaN      No     1
# 5           292.800000  Four-Door Car       Medsize            A      No     2
# 6           287.556107  Four-Door Car       Medsize          NaN      No     2
# 7           247.402353   Two-Door Car       Medsize          NaN      No     2
# 8           739.200000     Sports Car       Medsize          NaN     Yes     1
# 9           408.000000  Four-Door Car         Small          NaN      No     1
# 10          442.521087            SUV         Large            A      No     1
# 11          199.551735   Two-Door Car       Medsize          NaN      No     2
# 12           64.669515  Four-Door Car       Medsize          NaN      No     1
# 13          331.200000   Two-Door Car       Medsize            A      No     1
# 14          835.200000   Two-Door Car       Medsize          NaN      No     2
# 15          547.200000            SUV       Medsize          NaN     Yes     1
# 16          300.528579   Two-Door Car         Large            A      No     2
# 17          272.381465   Two-Door Car       Medsize            A      No     1
# 18          350.400000   Two-Door Car       Medsize            A      No     2
# 19           19.575683   Two-Door Car         Large            A     Yes     2
# 20          499.200000            SUV       Medsize            A      No     2
# 21          408.000000  Four-Door Car         Small          NaN      No     2
# 22          907.200000     Luxury Car         Large            A      No     1
# 23          128.900320  Four-Door Car       Medsize          NaN      No     2
# 24          355.200000  Four-Door Car       Medsize            A      No     2
# 25          123.154160            SUV         Small            A      No     1
# 26          228.185834            SUV         Large            A      No     2
# 27           60.036683  Four-Door Car       Medsize          NaN     Yes     2
# 28          234.774747  Four-Door Car       Medsize            A      No     2
# 29          313.192439  Four-Door Car       Medsize          NaN      No     1
# 30         1193.115879  Four-Door Car         Large            A      No     1
# 31          567.480550     Sports Car       Medsize          NaN      No     2
# 32          871.457982            SUV         Small            A      No     1
# 33          173.080024            SUV       Medsize          NaN      No     2
# 34          499.200000            SUV         Large          NaN      No     2
# 35          135.888306  Four-Door Car       Medsize          NaN      No     2
# 36          647.442031            SUV       Medsize          NaN      No     1
# 37          232.879766  Four-Door Car       Medsize          NaN      No     2
# 38          292.800000  Four-Door Car       Medsize          NaN      No     1
# 39          479.312226  Four-Door Car         Large            A      No     2
# 40          190.642833  Four-Door Car       Medsize            A      No     1
# 41          473.266879  Four-Door Car       Medsize          NaN      No     2
# 42          604.800000            SUV       Medsize            A      No     1
# 43           28.925840  Four-Door Car         Large            A      No     2
# 44          138.961963  Four-Door Car       Medsize          NaN      No     1
# 45          269.905129  Four-Door Car       Medsize            A      No     1
# 46          326.400000  Four-Door Car       Medsize          NaN      No     1
# 47          161.615740     Luxury SUV       Medsize          NaN      No     1
# 48          460.800000  Four-Door Car         Large            A      No     2
# 49          272.788141            SUV       Medsize            A      No     2
# 50          302.400000  Four-Door Car       Medsize            A      No     2
# 51          321.600000  Four-Door Car         Large            A      No     1
# 52          406.902001   Two-Door Car         Small          NaN      No     1
# 53          623.525433  Four-Door Car       Medsize          NaN      No     1
# 54          600.000000            SUV       Medsize          NaN      No     2
# 55         2294.631639     Luxury Car       Medsize            A      No     2
# 56          292.800000  Four-Door Car       Medsize          NaN      No     1
# 57          756.000000  Four-Door Car         Small            A      No     1
# 58          469.882367   Two-Door Car         Small          NaN      No     2
# 59          109.904496  Four-Door Car       Medsize          NaN      No     1
#
# [60 rows x 27 columns]

# %%
# There seems to be no March data as well as any other months except January and February.
# So the whole DataFrame shows only data for the first quarter? Not sure though.
customers['month'].where(customers['month'] == 2)
# Out:
# 0        2.0
# 1        NaN
# 2        2.0
# 3        NaN
# 4        NaN
#         ...
# 10905    NaN
# 10906    NaN
# 10907    2.0
# 10908    2.0
# 10909    NaN
# Name: month, Length: 10910, dtype: float64

# %%
customers.to_csv('marketing_customer_analysis_filtered.csv')

# %%
# LAB 3

# %%
import pandas as pd
import numpy as np

# %%
marke
